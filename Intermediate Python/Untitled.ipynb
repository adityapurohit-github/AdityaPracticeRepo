# %%
import matplotlib.pyplot as plt
year = [1910, 1930, 1950, 1970, 1990, 2010, 2030]
pop = [2.06,3.08,4.10,5.50,6.3,7.20,8.40]
plt.plot(year,pop)
plt.xlabel('Years')
plt.ylabel('Population')
plt.title('World Population')
plt.yticks([0,2,4,6,8,10],['0','2B', '4B','6B','8B','10B'])
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1910, 1930, 1950, 1970, 1990, 2010, 2030]
pop = [2.06,3.08,4.10,5.50,6.3,7.20,8.40]
plt.scatter(year,pop)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,3,4,5,6,44,22,88, 56,34,5,3,45,5,5,4,3,34,5,6]
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1910, 1930, 1950, 1970, 1990, 2010, 2030]
pop = [2.06,3.08,4.10,5.50,6.3,7.20,8.40]

#Add more data
year =[1800,1830,1860]+ [1910, 1930, 1950, 1970, 1990, 2010, 2030]
pop =[1.0,1.2,1.8] + [2.06,3.08,4.10,5.50,6.3,7.20,8.40]

plt.plot(year,pop)
plt.xlabel('Years')
plt.ylabel('Population')
plt.title('World Population')
plt.xticks([1800,1830,1860, 1910, 1930,1950,1970,1990,2010, 2030])
plt.yticks([0,2,4,6,8,10],['0','2B', '4B','6B','8B','10B'])
plt.show()
